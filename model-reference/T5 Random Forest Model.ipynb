# %%
import pandas as pd
import os

rdoge = pd.read_csv('data\R Doge SentimentPrice.csv');
rpepe = pd.read_csv('data\R Pepe SentimentPrice.csv');
rshiba = pd.read_csv('data\R Shiba SentimentPrice.csv');
rfloki = pd.read_csv('data\R Floki SentimentPrice.csv');

tdoge = pd.read_csv('data\Sorted Sent+Price - Doge.csv');
tpepe = pd.read_csv('data\Sorted Sent+Price - Pepe.csv');
tshiba = pd.read_csv('data\Sorted Sent+Price - Shiba.csv');
tfloki = pd.read_csv('data\Sorted Sent+Price - Floki.csv');

rdoge = rfloki.drop(columns=['Unnamed: 0'])
rpepe = rpepe.drop(columns=['Unnamed: 0'])
rshiba = rshiba.drop(columns=['Unnamed: 0'])
rfloki = rfloki.drop(columns=['Unnamed: 0'])

tdoge = tfloki.drop(columns=['Unnamed: 0', 'Unnamed: 0.1']).rename(columns={'mentions_shiba inu':'mentions_shiba_inu'})
tpepe = tpepe.drop(columns=['Unnamed: 0']).rename(columns={'mentions_shiba inu':'mentions_shiba_inu'})
tshiba = tshiba.drop(columns=['Unnamed: 0']).rename(columns={'mentions_shiba inu':'mentions_shiba_inu'})
tfloki = tfloki.drop(columns=['Unnamed: 0', 'Unnamed: 0.1']).rename(columns={'mentions_shiba inu':'mentions_shiba_inu'})

# tdoge = tdoge.drop(columns=['Unnamed: 0.1'])
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\R'
# <>:4: SyntaxWarning: invalid escape sequence '\R'
# <>:5: SyntaxWarning: invalid escape sequence '\R'
# <>:6: SyntaxWarning: invalid escape sequence '\R'
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\S'
# <>:10: SyntaxWarning: invalid escape sequence '\S'
# <>:11: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\R'
# <>:4: SyntaxWarning: invalid escape sequence '\R'
# <>:5: SyntaxWarning: invalid escape sequence '\R'
# <>:6: SyntaxWarning: invalid escape sequence '\R'
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\S'
# <>:10: SyntaxWarning: invalid escape sequence '\S'
# <>:11: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\4087138460.py:3: SyntaxWarning: invalid escape sequence '\R'
#   rdoge = pd.read_csv('data\R Doge SentimentPrice.csv');
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\4087138460.py:4: SyntaxWarning: invalid escape sequence '\R'
#   rpepe = pd.read_csv('data\R Pepe SentimentPrice.csv');
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\4087138460.py:5: SyntaxWarning: invalid escape sequence '\R'
#   rshiba = pd.read_csv('data\R Shiba SentimentPrice.csv');
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\4087138460.py:6: SyntaxWarning: invalid escape sequence '\R'
#   rfloki = pd.read_csv('data\R Floki SentimentPrice.csv');
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\4087138460.py:8: SyntaxWarning: invalid escape sequence '\S'
#   tdoge = pd.read_csv('data\Sorted Sent+Price - Doge.csv');
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\4087138460.py:9: SyntaxWarning: invalid escape sequence '\S'
#   tpepe = pd.read_csv('data\Sorted Sent+Price - Pepe.csv');
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\4087138460.py:10: SyntaxWarning: invalid escape sequence '\S'
#   tshiba = pd.read_csv('data\Sorted Sent+Price - Shiba.csv');
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\4087138460.py:11: SyntaxWarning: invalid escape sequence '\S'
#   tfloki = pd.read_csv('data\Sorted Sent+Price - Floki.csv');

# %%
print(rdoge.head(0))
print(rpepe.head(0))
print(rshiba.head(0))
print(rfloki.head(0))

print(tdoge.head(0))
print(tpepe.head(0))
print(tshiba.head(0))
print(tfloki.head(0))
# Out:
# Empty DataFrame
# Columns: [Date, clean_text, sentiment, compound_score, positive_score, negative_score, neutral_score, sentiment_category, mentions_dogecoin, mentions_shiba_inu, mentions_pepe, mentions_floki, mentions_bonk, mentions_wojak, mentions_other, Close, Open, High, Low, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, clean_text, sentiment, compound_score, positive_score, negative_score, neutral_score, sentiment_category, mentions_dogecoin, mentions_shiba_inu, mentions_pepe, mentions_floki, mentions_bonk, mentions_wojak, mentions_other, Close, Open, High, Low, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, clean_text, sentiment, compound_score, positive_score, negative_score, neutral_score, sentiment_category, mentions_dogecoin, mentions_shiba_inu, mentions_pepe, mentions_floki, mentions_bonk, mentions_wojak, mentions_other, Close, Open, High, Low, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, clean_text, sentiment, compound_score, positive_score, negative_score, neutral_score, sentiment_category, mentions_dogecoin, mentions_shiba_inu, mentions_pepe, mentions_floki, mentions_bonk, mentions_wojak, mentions_other, Close, Open, High, Low, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, clean_text, sentiment, compound_score, positive_score, negative_score, neutral_score, sentiment_category, mentions_dogecoin, mentions_shiba_inu, mentions_pepe, mentions_floki, mentions_bonk, mentions_wojak, mentions_other, Close, Open, High, Low, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, clean_text, sentiment, compound_score, positive_score, negative_score, neutral_score, sentiment_category, mentions_dogecoin, mentions_shiba_inu, mentions_pepe, mentions_floki, mentions_bonk, mentions_wojak, mentions_other, Close, Open, High, Low, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, clean_text, sentiment, compound_score, positive_score, negative_score, neutral_score, sentiment_category, mentions_dogecoin, mentions_shiba_inu, mentions_pepe, mentions_floki, mentions_bonk, mentions_wojak, mentions_other, Close, Open, High, Low, Volume]
# Index: []
# Empty DataFrame
# Columns: [Date, clean_text, sentiment, compound_score, positive_score, negative_score, neutral_score, sentiment_category, mentions_dogecoin, mentions_shiba_inu, mentions_pepe, mentions_floki, mentions_bonk, mentions_wojak, mentions_other, Close, Open, High, Low, Volume]
# Index: []

# %%
for df in [tdoge, tshiba, tpepe, tfloki, rdoge,rshiba, rpepe, rfloki]:
    print(len(df))
    print(df.isna().sum())
# Out:
# 114
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 4110
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 378
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 114
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 4358
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 28075
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 42693
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 4358
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64

# %%
for df in [tdoge, tshiba, tpepe, tfloki, rdoge,rshiba, rpepe, rfloki]:
    print(df['Volume'].map(type).value_counts())
# Out:
# Volume
# <class 'str'>    114
# Name: count, dtype: int64
# Volume
# <class 'str'>    4110
# Name: count, dtype: int64
# Volume
# <class 'float'>    378
# Name: count, dtype: int64
# Volume
# <class 'str'>    114
# Name: count, dtype: int64
# Volume
# <class 'str'>    4358
# Name: count, dtype: int64
# Volume
# <class 'str'>    28075
# Name: count, dtype: int64
# Volume
# <class 'float'>    42693
# Name: count, dtype: int64
# Volume
# <class 'str'>    4358
# Name: count, dtype: int64

# %%
for df in [tdoge, tshiba, tpepe, tfloki, rdoge,rshiba, rpepe, rfloki]:
    print(df['Volume'].head(5))
# Out:
# 0    14.45B
# 1    19.67B
# 2     7.41B
# 3     8.79B
# 4     8.79B
# Name: Volume, dtype: object
# 0    90,522.63B
# 1    90,522.63B
# 2    90,522.63B
# 3    90,522.63B
# 4    90,522.63B
# Name: Volume, dtype: object
# 0    7.395420e+07
# 1    7.395420e+07
# 2    7.395420e+07
# 3    7.395420e+07
# 4    1.700563e+08
# Name: Volume, dtype: float64
# 0    14.45B
# 1    19.67B
# 2     7.41B
# 3     8.79B
# 4     8.79B
# Name: Volume, dtype: object
# 0    15.86B
# 1    15.86B
# 2    15.86B
# 3    15.86B
# 4    15.86B
# Name: Volume, dtype: object
# 0    86,848.92B
# 1    86,848.92B
# 2    86,848.92B
# 3    86,848.92B
# 4    86,848.92B
# Name: Volume, dtype: object
# 0    1988.31
# 1    1988.31
# 2    1988.31
# 3    1988.31
# 4    1630.18
# Name: Volume, dtype: float64
# 0    15.86B
# 1    15.86B
# 2    15.86B
# 3    15.86B
# 4    15.86B
# Name: Volume, dtype: object

# %%
def convert_volume(val):
    import pandas as pd
    
    if pd.isna(val):
        return None

    if isinstance(val, (int, float)):
        return float(val)  # Already numeric

    val = str(val).replace(',', '')  # Remove commas

    multiplier = 1
    if val.endswith('B'):
        multiplier = 1_000_000_000
        val = val[:-1]
    elif val.endswith('M'):
        multiplier = 1_000_000
        val = val[:-1]
    elif val.endswith('K'):
        multiplier = 1_000
        val = val[:-1]

    try:
        return float(val) * multiplier
    except ValueError:
        return None  # or np.nan

# %%
for df in [tdoge, tshiba, tpepe, tfloki, rdoge,rshiba, rpepe, rfloki]:
    df['Volume'] = df['Volume'].apply(convert_volume)

# %%
for df in [tdoge, tshiba, tpepe, tfloki, rdoge,rshiba, rpepe, rfloki]:
    print(df['Volume'].map(type).value_counts())
    print(df['Volume'].isna().sum())
    print(df['Date'].head(1))
# Out:
# Volume
# <class 'float'>    114
# Name: count, dtype: int64
# 0
# 0    2023-02-02
# Name: Date, dtype: object
# Volume
# <class 'float'>    4110
# Name: count, dtype: int64
# 0
# 0    2021-05-19
# Name: Date, dtype: object
# Volume
# <class 'float'>    378
# Name: count, dtype: int64
# 0
# 0    2023-04-18
# Name: Date, dtype: object
# Volume
# <class 'float'>    114
# Name: count, dtype: int64
# 0
# 0    2023-02-02
# Name: Date, dtype: object
# Volume
# <class 'float'>    4358
# Name: count, dtype: int64
# 0
# 0    30-01-2023
# Name: Date, dtype: object
# Volume
# <class 'float'>    28075
# Name: count, dtype: int64
# 0
# 0    12-05-2021
# Name: Date, dtype: object
# Volume
# <class 'float'>    42693
# Name: count, dtype: int64
# 0
# 0    15-04-2023
# Name: Date, dtype: object
# Volume
# <class 'float'>    4358
# Name: count, dtype: int64
# 0
# 0    30-01-2023
# Name: Date, dtype: object

# %%
for df in [tdoge, tshiba, tpepe, tfloki, rdoge,rshiba, rpepe, rfloki]:
    # Step 1: Parse dates safely (handles mixed formats)
    df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')

    # Step 2: Drop rows where date couldn't be parsed
    df.dropna(subset=['Date'], inplace=True)

    # Step 3: Convert to string format YYYY-MM-DD (optional, only if you need it as string)
    df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')

    # If you're doing time series modeling, keep it as datetime (skip step 3)
# Out:
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\2279058134.py:3: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\2279058134.py:3: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')

# %%
for df in [tdoge, tshiba, tpepe, tfloki, rdoge,rshiba, rpepe, rfloki]:
    print(df['Date'].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
# Concatenate matching pairs
doge_df = pd.concat([rdoge, tdoge], ignore_index=True)
pepe_df = pd.concat([rpepe, tpepe], ignore_index=True)
shiba_df = pd.concat([rshiba, tshiba], ignore_index=True)
floki_df = pd.concat([rfloki, tfloki], ignore_index=True)

# %%
for df in [tdoge, tshiba, tpepe, tfloki, rdoge,rshiba, rpepe, rfloki]:
    print(df['Date'].head(1))
# Out:
# 0    2023-02-02
# Name: Date, dtype: object
# 0    2021-05-19
# Name: Date, dtype: object
# 0    2023-04-18
# Name: Date, dtype: object
# 0    2023-02-02
# Name: Date, dtype: object
# 0    2023-01-30
# Name: Date, dtype: object
# 0    2021-05-12
# Name: Date, dtype: object
# 0    2023-04-15
# Name: Date, dtype: object
# 0    2023-01-30
# Name: Date, dtype: object

# %%
for df in [doge_df, pepe_df, shiba_df, floki_df]:
    print(df['Volume'].isna().sum())  
    print(df['Date'].head(1))
# Out:
# 0
# 0    2023-01-30
# Name: Date, dtype: object
# 0
# 0    2023-04-15
# Name: Date, dtype: object
# 0
# 0    2021-05-12
# Name: Date, dtype: object
# 0
# 0    2023-01-30
# Name: Date, dtype: object

# %%
# for df in [doge_df, pepe_df, shiba_df, floki_df]:
print(doge_df['Volume'].map(type).value_counts())
print(shiba_df['Volume'].map(type).value_counts())
print(pepe_df['Volume'].map(type).value_counts())
print(floki_df['Volume'].map(type).value_counts())
# Out:
# Volume
# <class 'float'>    4412
# Name: count, dtype: int64
# Volume
# <class 'float'>    32185
# Name: count, dtype: int64
# Volume
# <class 'float'>    43071
# Name: count, dtype: int64
# Volume
# <class 'float'>    4412
# Name: count, dtype: int64

# %%
for df in [doge_df, shiba_df, floki_df]:
    print(df.isna().sum())
    print(len(df))
# Out:
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 4412
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 32185
# Date                  0
# clean_text            0
# sentiment             0
# compound_score        0
# positive_score        0
# negative_score        0
# neutral_score         0
# sentiment_category    0
# mentions_dogecoin     0
# mentions_shiba_inu    0
# mentions_pepe         0
# mentions_floki        0
# mentions_bonk         0
# mentions_wojak        0
# mentions_other        0
# Close                 0
# Open                  0
# High                  0
# Low                   0
# Volume                0
# dtype: int64
# 4412

# %%
doge_group = doge_df.groupby('Date').agg({
    'compound_score': 'mean',
    'positive_score': 'mean',
    'neutral_score': 'mean',
    'negative_score': 'mean',
    'Open': 'first',
    'Close': 'first',
    'High': 'first',
    'Low': 'first',
    'Volume': 'mean'
}).reset_index()

shiba_group = shiba_df.groupby('Date').agg({
    'compound_score': 'mean',
    'positive_score': 'mean',
    'neutral_score': 'mean',
    'negative_score': 'mean',
    'Open': 'first',
    'Close': 'first',
    'High': 'first',
    'Low': 'first',
    'Volume': 'mean'
}).reset_index()

pepe_group = pepe_df.groupby('Date').agg({
    'compound_score': 'mean',
    'positive_score': 'mean',
    'neutral_score': 'mean',
    'negative_score': 'mean',
    'Open': 'first',
    'Close': 'first',
    'High': 'first',
    'Low': 'first',
    'Volume': 'mean'
}).reset_index()

floki_group = floki_df.groupby('Date').agg({
    'compound_score': 'mean',
    'positive_score': 'mean',
    'neutral_score': 'mean',
    'negative_score': 'mean',
    'Open': 'first',
    'Close': 'first',
    'High': 'first',
    'Low': 'first',
    'Volume': 'mean'
}).reset_index()

# %%
for df in [doge_group, pepe_group, shiba_group, floki_group]:
    print(df.isna().sum())
    print(len(df))
# Out:
# Date              0
# compound_score    0
# positive_score    0
# neutral_score     0
# negative_score    0
# Open              0
# Close             0
# High              0
# Low               0
# Volume            0
# dtype: int64
# 640
# Date              0
# compound_score    0
# positive_score    0
# neutral_score     0
# negative_score    0
# Open              0
# Close             0
# High              0
# Low               0
# Volume            0
# dtype: int64
# 625
# Date              0
# compound_score    0
# positive_score    0
# neutral_score     0
# negative_score    0
# Open              0
# Close             0
# High              0
# Low               0
# Volume            0
# dtype: int64
# 1304
# Date              0
# compound_score    0
# positive_score    0
# neutral_score     0
# negative_score    0
# Open              0
# Close             0
# High              0
# Low               0
# Volume            0
# dtype: int64
# 640

# %%
doge_group.head(5)
# Out:
#          Date  compound_score  positive_score  neutral_score  negative_score  \
# 0  2023-01-30        0.260150        0.106167       0.848333          0.0455
# 1  2023-01-31        0.355044        0.149111       0.846000          0.0050
# 2  2023-02-01        0.718840        0.391200       0.557800          0.0510
# 3  2023-02-02        0.285800        0.100667       0.899333          0.0000
# 4  2023-02-03        0.449600        0.254000       0.651000          0.0950
#
#        Open     Close      High       Low        Volume
# 0  0.000024  0.000025  0.000028  0.000021  1.586000e+10
# 1  0.000025  0.000024  0.000026  0.000022  1.305000e+10
# 2  0.000024  0.000025  0.000025  0.000022  1.034000e+10
# 3  0.000025  0.000025  0.000027  0.000024  1.445000e+10
# 4  0.000025  0.000026  0.000026  0.000022  1.437000e+10

# %%
print("Doge stats:")
print(doge_group[['Open', 'High', 'Low', 'Close']].describe())
print("Variance per target:")
print(doge_group[['Open', 'High', 'Low', 'Close']].var())

print("Shiba stats:")
print(shiba_group[['Open', 'High', 'Low', 'Close']].describe())
print("Variance per target:")
print(shiba_group[['Open', 'High', 'Low', 'Close']].var())

print("Pepe stats:")
print(pepe_group[['Open', 'High', 'Low', 'Close']].describe())
print("Variance per target:")
print(pepe_group[['Open', 'High', 'Low', 'Close']].var())

print("Floki stats:")
print(floki_group[['Open', 'High', 'Low', 'Close']].describe())
print("Variance per target:")
print(floki_group[['Open', 'High', 'Low', 'Close']].var())
# Out:
# Doge stats:
#              Open        High         Low       Close
# count  640.000000  640.000000  640.000000  640.000000
# mean     0.000099    0.000106    0.000094    0.000099
# std      0.000082    0.000088    0.000077    0.000082
# min      0.000015    0.000016    0.000015    0.000015
# 25%      0.000031    0.000032    0.000029    0.000031
# 50%      0.000041    0.000045    0.000038    0.000041
# 75%      0.000169    0.000177    0.000161    0.000169
# max      0.000322    0.000348    0.000304    0.000323
# Variance per target:
# Open     6.739715e-09
# High     7.719788e-09
# Low      5.927550e-09
# Close    6.731979e-09
# dtype: float64
# Shiba stats:
#               Open         High          Low        Close
# count  1304.000000  1304.000000  1304.000000  1304.000000
# mean      0.000016     0.000017     0.000015     0.000016
# std       0.000010     0.000011     0.000009     0.000010
# min       0.000006     0.000006     0.000005     0.000006
# 25%       0.000009     0.000009     0.000008     0.000009
# 50%       0.000012     0.000012     0.000011     0.000012
# 75%       0.000022     0.000023     0.000021     0.000022
# max       0.000079     0.000088     0.000067     0.000079
# Variance per target:
# Open     1.043759e-10
# High     1.222130e-10
# Low      8.787458e-11
# Close    1.041816e-10
# dtype: float64
# Pepe stats:
#                Open          High           Low         Close
# count  6.250000e+02  6.250000e+02  6.250000e+02  6.250000e+02
# mean   6.071181e-06  6.441739e-06  5.743408e-06  6.101282e-06
# std    6.055245e-06  6.417688e-06  5.718990e-06  6.070352e-06
# min    1.898400e-10  7.654880e-09  1.898400e-10  7.620320e-09
# 25%    1.158776e-06  1.213008e-06  1.104146e-06  1.163582e-06
# 50%    2.007908e-06  2.942888e-06  1.778591e-06  2.651753e-06
# 75%    9.279832e-06  9.884692e-06  8.874442e-06  9.318530e-06
# max    2.640453e-05  2.824725e-05  2.433484e-05  2.640453e-05
# Variance per target:
# Open     3.666600e-11
# High     4.118672e-11
# Low      3.270684e-11
# Close    3.684917e-11
# dtype: float64
# Floki stats:
#              Open        High         Low       Close
# count  640.000000  640.000000  640.000000  640.000000
# mean     0.000099    0.000106    0.000094    0.000099
# std      0.000082    0.000088    0.000077    0.000082
# min      0.000015    0.000016    0.000015    0.000015
# 25%      0.000031    0.000032    0.000029    0.000031
# 50%      0.000041    0.000045    0.000038    0.000041
# 75%      0.000169    0.000177    0.000161    0.000169
# max      0.000322    0.000348    0.000304    0.000323
# Variance per target:
# Open     6.739715e-09
# High     7.719788e-09
# Low      5.927550e-09
# Close    6.731979e-09
# dtype: float64

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import os
import joblib

# Helper function to train Random Forest with GridSearchCV for a single target
def train_rf_with_gridsearch(df, target):
    X = df[['compound_score']].values
    y = df[target].values

    # scaler_X = StandardScaler()
    # X_scaled = scaler_X.fit_transform(X)

    scaler_X = StandardScaler()
    scaler_y = StandardScaler()
    X_scaled = scaler_X.fit_transform(X)
    y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).ravel()

    # Train/test split (non-shuffled for time series)
    split_idx = int(len(X_scaled) * 0.8)
    X_train, X_test = X_scaled[:split_idx], X_scaled[split_idx:]
    y_train, y_test = y_scaled[:split_idx], y[split_idx:]

    param_grid = {
        "n_estimators": [50, 100, 200],
        "max_depth": [None, 5, 10],
        "min_samples_split": [2, 5],
        "min_samples_leaf": [1, 2]
    }
    grid_search = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # Predictions on test set
    y_pred_scaled = grid_search.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()
    y_test_inv = scaler_y.inverse_transform(y_test.reshape(-1, 1)).ravel()

    # Predictions on entire dataset
    y_full_pred_scaled = grid_search.predict(X_scaled)
    y_full_pred = scaler_y.inverse_transform(y_full_pred_scaled.reshape(-1, 1)).ravel()

    last_date = pd.to_datetime(df['Date'].max())
    today = pd.to_datetime(datetime.today().date())  # Now this works
    num_days = (today - last_date).days

    if num_days <= 0:
        print("No prediction needed — data is already up to date.")
    else:
        # Generate future dates
        future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=num_days)

    # Future forecast
    future_scores = np.linspace(-1, 1, num_days).reshape(-1, 1)
    future_scaled = scaler_X.transform(future_scores)
    # last_volume = df['Volume'].iloc[-1]
    # future_compound_scores = np.linspace(-1, 1, num_days)
    # future_data = np.column_stack((future_compound_scores, [last_volume] * num_days))
    # future_scaled = scaler_X.transform(future_data)
    future_pred_scaled = grid_search.predict(future_scaled)
    future_pred = scaler_y.inverse_transform(future_pred_scaled.reshape(-1, 1)).ravel()

    return {
        "model": grid_search.best_estimator_,
        "mse": mean_squared_error(y_test_inv, y_pred),
        "dates": df['Date'].values,
        "predictions": y_pred,
        "actuals": y_test_inv,
        "future_forecast": future_pred,
        "best_params": grid_search.best_params_,
        "full_predictions": y_full_pred,
        "full_actuals": y,
        "scaler_X": scaler_X,
        "scaler_y": scaler_y,
    }

datasets = {
    "doge": doge_group,
    "shiba": shiba_group,
    "pepe": pepe_group,
    "floki": floki_group
}

targets = ['Open', 'High', 'Low', 'Close']
results_rf = {}

for coin, df in datasets.items():
    df = df.sort_values('Date').dropna()
    results_rf[coin] = {}
    for target in targets:
        res = train_rf_with_gridsearch(df, target)
        results_rf[coin][target] = res
        
        model_dir = "saved_models2"
        os.makedirs(model_dir, exist_ok=True)  # Create folder if it doesn't exist
        model_path1 = os.path.join(model_dir, f"{coin}_{target}_rf_model.joblib")
        model_path2 = os.path.join(model_dir, f"{coin}_{target}_rf_scaler_X.joblib")
        model_path3 = os.path.join(model_dir, f"{coin}_{target}_rf_scaler_y.joblib")

        # Save the trained model
        joblib.dump(res["model"], model_path1)
        joblib.dump(res['scaler_X'], model_path2)
        joblib.dump(res['scaler_y'], model_path3)

# %%
# Plotting results for Random Forest
for coin in results_rf:
    print(f"\n=== {coin.upper()} ===")
    df = datasets[coin]
    df = df.sort_values('Date').dropna()

    print(df.head(5))  # Show first few rows for context

    for target in targets:
        res = results_rf[coin][target]
        r2 = r2_score(res['actuals'], res['predictions'])

        print(f"\nTarget: {target}")
        print(f"Best Params: {res['best_params']}")
        print(f"Mean Squared Error (MSE): {res['mse']:.8f}")
        print(f"R² Score: {r2:.4f}")

        print("\nPredicted vs Actual (first 20 test samples):")
        for i in range(min(10, len(res["predictions"]))):
            pred = res["predictions"][i]
            actual = res["actuals"][i]
            print(f"  Predicted: {pred:.6f} | Actual: {actual:.6f}")

        last_date = pd.to_datetime(df['Date'].max())
        future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=len(res["future_forecast"]))
        future_dates = future_dates.to_pydatetime()

        test_dates = pd.to_datetime(datasets[coin]['Date'].iloc[-len(res['actuals']):], errors='coerce').dt.to_pydatetime()
        # df = df.sort_values('Date').reset_index(drop=True)

        # Verify length match
        assert len(df) == len(res['full_predictions']), "Length mismatch"
        
        # Plot full dataset actuals vs full predictions
        full_dates = pd.to_datetime(df['Date'])

        print("\nForecasted Future Values (based on future compound_score):")
        for date, forecast in zip(future_dates, res["future_forecast"]):
            print(f"  {date.date()} -> Predicted {target}: {forecast:.6f}")

        # Plot full dataset actuals vs full predictions
        df = df.copy()
        df['Date'] = pd.to_datetime(df['Date'])
        full_dates = df['Date']
        last_date = df['Date'].max()

        plt.figure(figsize=(12, 5))
        plt.plot(full_dates, res["full_actuals"], label="Actual", linestyle='--')
        plt.plot(full_dates, res["full_predictions"], label="Predicted (Full Dataset)", alpha=0.7)
        plt.plot(future_dates, res["future_forecast"], label="Forecasted Future")

        plt.title(f"{coin.upper()} - {target} Price Prediction & Forecast (Random Forest)")
        plt.xlabel("Date")
        plt.ylabel(f"{target} Price")
        plt.xticks(rotation=45)
        plt.legend()
        plt.tight_layout()
        plt.show()
# Out:
# === DOGE ===
#          Date  compound_score  positive_score  neutral_score  negative_score  \
# 0  2023-01-30        0.260150        0.106167       0.848333          0.0455
# 1  2023-01-31        0.355044        0.149111       0.846000          0.0050
# 2  2023-02-01        0.718840        0.391200       0.557800          0.0510
# 3  2023-02-02        0.285800        0.100667       0.899333          0.0000
# 4  2023-02-03        0.449600        0.254000       0.651000          0.0950
#
#        Open     Close      High       Low        Volume
# 0  0.000024  0.000025  0.000028  0.000021  1.586000e+10
# 1  0.000025  0.000024  0.000026  0.000022  1.305000e+10
# 2  0.000024  0.000025  0.000025  0.000022  1.034000e+10
# 3  0.000025  0.000025  0.000027  0.000024  1.445000e+10
# 4  0.000025  0.000026  0.000026  0.000022  1.437000e+10
#
# Target: Open
# Best Params: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Mean Squared Error (MSE): 0.00000000
# R² Score: -62686462.9624
#
# Predicted vs Actual (first 20 test samples):
#   Predicted: 0.000092 | Actual: 0.000099
#   Predicted: 0.000038 | Actual: 0.000099
#   Predicted: 0.000104 | Actual: 0.000099
#   Predicted: 0.000063 | Actual: 0.000099
#   Predicted: 0.000111 | Actual: 0.000099
#   Predicted: 0.000100 | Actual: 0.000099
#   Predicted: 0.000092 | Actual: 0.000099
#   Predicted: 0.000103 | Actual: 0.000099
#   Predicted: 0.000081 | Actual: 0.000099
#   Predicted: 0.000039 | Actual: 0.000099
#
# Forecasted Future Values (based on future compound_score):
#   2025-01-02 -> Predicted Open: 0.000033
#   2025-01-03 -> Predicted Open: 0.000033
#   2025-01-04 -> Predicted Open: 0.000033
#   2025-01-05 -> Predicted Open: 0.000033
#   2025-01-06 -> Predicted Open: 0.000033
#   2025-01-07 -> Predicted Open: 0.000033
#   2025-01-08 -> Predicted Open: 0.000033
#   2025-01-09 -> Predicted Open: 0.000033
#   2025-01-10 -> Predicted Open: 0.000033
#   2025-01-11 -> Predicted Open: 0.000033
#   2025-01-12 -> Predicted Open: 0.000033
#   2025-01-13 -> Predicted Open: 0.000033
#   2025-01-27 -> Predicted Close: 0.000033
#   2025-01-28 -> Predicted Close: 0.000033
#   2025-01-29 -> Predicted Close: 0.000033
#   2025-01-30 -> Predicted Close: 0.000033
#   2025-01-31 -> Predicted Close: 0.000033
#   2025-02-01 -> Predicted Close: 0.000033
#   2025-02-02 -> Predicted Close: 0.000034
#   2025-02-03 -> Predicted Close: 0.000034
#   2025-02-04 -> Predicted Close: 0.000033
#   2025-02-05 -> Predicted Close: 0.000035
#   2025-02-06 -> Predicted Close: 0.000035
#   2025-02-07 -> Predicted Close: 0.000035
#   2025-02-08 -> Predicted Close: 0.000035
#   2025-02-09 -> Predicted Close: 0.000042
#   2025-02-10 -> Predicted Close: 0.000042
#   2025-02-11 -> Predicted Close: 0.000042
#   2025-02-12 -> Predicted Close: 0.000045
#   2025-02-13 -> Predicted Close: 0.000045
#   2025-02-14 -> Predicted Close: 0.000041
#   2025-02-15 -> Predicted Close: 0.000041
#   2025-02-16 -> Predicted Close: 0.000041
#   2025-02-17 -> Predicted Close: 0.000041
#   2025-02-18 -> Predicted Close: 0.000041
#   2025-02-19 -> Predicted Close: 0.000041
#   2025-02-20 -> Predicted Close: 0.000055
#   2025-02-21 -> Predicted Close: 0.000055
#   2025-02-22 -> Predicted Close: 0.000111
#   2025-02-23 -> Predicted Close: 0.000111
#   2025-02-24 -> Predicted Close: 0.000111
#   2025-02-25 -> Predicted Close: 0.000136
#   2025-02-26 -> Predicted Close: 0.000136
#   2025-02-27 -> Predicted Close: 0.000139
#   2025-02-28 -> Predicted Close: 0.000139
#   2025-03-01 -> Predicted Close: 0.000139
#   2025-03-02 -> Predicted Close: 0.000141
#   2025-03-03 -> Predicted Close: 0.000141
#   2025-03-04 -> Predicted Close: 0.000129
#   2025-03-05 -> Predicted Close: 0.000127
#   2025-03-06 -> Predicted Close: 0.000095
#   2025-03-07 -> Predicted Close: 0.000093
#   2025-03-08 -> Predicted Close: 0.000085
#   2025-03-09 -> Predicted Close: 0.000094
#   2025-03-10 -> Predicted Close: 0.000052
#   2025-03-11 -> Predicted Close: 0.000052
#   2025-03-12 -> Predicted Close: 0.000046
#   2025-03-13 -> Predicted Close: 0.000045
#   2025-03-14 -> Predicted Close: 0.000045
#   2025-03-15 -> Predicted Close: 0.000045
#   2025-03-16 -> Predicted Close: 0.000045
#   2025-03-17 -> Predicted Close: 0.000043
#   2025-03-18 -> Predicted Close: 0.000046
#   2025-03-19 -> Predicted Close: 0.000054
#   2025-03-20 -> Predicted Close: 0.000069
#   2025-03-21 -> Predicted Close: 0.000060
#   2025-03-22 -> Predicted Close: 0.000059
#   2025-03-23 -> Predicted Close: 0.000096
#   2025-03-24 -> Predicted Close: 0.000113
#   2025-03-25 -> Predicted Close: 0.000111
#   2025-03-26 -> Predicted Close: 0.000101
#   2025-03-27 -> Predicted Close: 0.000095
#   2025-03-28 -> Predicted Close: 0.000097
#   2025-03-29 -> Predicted Close: 0.000119
#   2025-03-30 -> Predicted Close: 0.000117
#   2025-03-31 -> Predicted Close: 0.000117
#   2025-04-01 -> Predicted Close: 0.000112
#   2025-04-02 -> Predicted Close: 0.000102
#   2025-04-03 -> Predicted Close: 0.000104
#   2025-04-04 -> Predicted Close: 0.000104
#   2025-04-05 -> Predicted Close: 0.000101
#   2025-04-06 -> Predicted Close: 0.000099
#   2025-04-07 -> Predicted Close: 0.000100
#   2025-04-08 -> Predicted Close: 0.000092
#   2025-04-09 -> Predicted Close: 0.000092
#   2025-04-10 -> Predicted Close: 0.000109
#   2025-04-11 -> Predicted Close: 0.000092
#   2025-04-12 -> Predicted Close: 0.000128
#   2025-04-13 -> Predicted Close: 0.000118
#   2025-04-14 -> Predicted Close: 0.000110
#   2025-04-15 -> Predicted Close: 0.000096
#   2025-04-16 -> Predicted Close: 0.000138
#   2025-04-17 -> Predicted Close: 0.000138
#   2025-04-18 -> Predicted Close: 0.000096
#   2025-04-19 -> Predicted Close: 0.000100
#   2025-04-20 -> Predicted Close: 0.000089
#   2025-04-21 -> Predicted Close: 0.000109
#   2025-04-22 -> Predicted Close: 0.000107
#   2025-04-23 -> Predicted Close: 0.000103
#   2025-04-24 -> Predicted Close: 0.000096
#   2025-04-25 -> Predicted Close: 0.000099
#   2025-04-26 -> Predicted Close: 0.000091
#   2025-04-27 -> Predicted Close: 0.000092
#   2025-04-28 -> Predicted Close: 0.000085
#   2025-04-29 -> Predicted Close: 0.000099
#   2025-04-30 -> Predicted Close: 0.000085
#   2025-05-01 -> Predicted Close: 0.000082
#   2025-05-02 -> Predicted Close: 0.000099
#   2025-05-03 -> Predicted Close: 0.000093
#   2025-05-04 -> Predicted Close: 0.000088
#   2025-05-05 -> Predicted Close: 0.000092
#   2025-05-06 -> Predicted Close: 0.000085
#   2025-05-07 -> Predicted Close: 0.000095
#   2025-05-08 -> Predicted Close: 0.000084
#   2025-05-09 -> Predicted Close: 0.000077
#   2025-05-10 -> Predicted Close: 0.000078
#   2025-05-11 -> Predicted Close: 0.000082
#   2025-05-12 -> Predicted Close: 0.000081
#   2025-05-13 -> Predicted Close: 0.000090
#   2025-05-14 -> Predicted Close: 0.000057
#   2025-05-15 -> Predicted Close: 0.000056
#   2025-05-16 -> Predicted Close: 0.000038
#   2025-05-17 -> Predicted Close: 0.000041
#   2025-05-18 -> Predicted Close: 0.000119
#   2025-05-19 -> Predicted Close: 0.000032
#   2025-05-20 -> Predicted Close: 0.000029
#   2025-05-21 -> Predicted Close: 0.000030
#   2025-05-22 -> Predicted Close: 0.000030
#   2025-05-23 -> Predicted Close: 0.000029
#   2025-05-24 -> Predicted Close: 0.000041
#   2025-05-25 -> Predicted Close: 0.000039
#   2025-05-26 -> Predicted Close: 0.000038
#   2025-05-27 -> Predicted Close: 0.000059
#   2025-05-28 -> Predicted Close: 0.000038
#   2025-05-29 -> Predicted Close: 0.000038
#   2025-05-30 -> Predicted Close: 0.000045
#   2025-05-31 -> Predicted Close: 0.000043
#   2025-06-01 -> Predicted Close: 0.000060
#   2025-06-02 -> Predicted Close: 0.000068
#   2025-06-03 -> Predicted Close: 0.000066
#   2025-06-04 -> Predicted Close: 0.000051
#   2025-06-05 -> Predicted Close: 0.000060
#   2025-06-06 -> Predicted Close: 0.000083
#   2025-06-07 -> Predicted Close: 0.000060
#   2025-06-08 -> Predicted Close: 0.000058
#   2025-06-09 -> Predicted Close: 0.000049
#   2025-06-10 -> Predicted Close: 0.000047
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\3642910970.py:28: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   test_dates = pd.to_datetime(datasets[coin]['Date'].iloc[-len(res['actuals']):], errors='coerce').dt.to_pydatetime()
# === SHIBA ===
#          Date  compound_score  positive_score  neutral_score  negative_score  \
# 0  2021-05-12        0.217253        0.142751       0.793253        0.063986
# 1  2021-05-13        0.285077        0.170476       0.751150        0.078384
# 2  2021-05-14        0.342112        0.168340       0.775025        0.056594
# 3  2021-05-15        0.271369        0.162225       0.759721        0.078061
# 4  2021-05-16        0.297645        0.170284       0.762624        0.067108
#
#        Open     Close      High       Low        Volume
# 0  0.000030  0.000018  0.000030  0.000018  8.684892e+13
# 1  0.000018  0.000021  0.000021  0.000016  9.138221e+13
# 2  0.000021  0.000018  0.000021  0.000018  4.092923e+13
# 3  0.000018  0.000016  0.000018  0.000015  4.372410e+13
# 4  0.000016  0.000018  0.000018  0.000013  6.161436e+13
#
# Target: Open
# Best Params: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Mean Squared Error (MSE): 0.00000000
# R² Score: -5975983905.5458
#
# Predicted vs Actual (first 20 test samples):
#   Predicted: 0.000013 | Actual: 0.000016
#   Predicted: 0.000017 | Actual: 0.000016
#   Predicted: 0.000013 | Actual: 0.000016
#   Predicted: 0.000018 | Actual: 0.000016
#   Predicted: 0.000017 | Actual: 0.000016
#   Predicted: 0.000015 | Actual: 0.000016
#   Predicted: 0.000017 | Actual: 0.000016
#   Predicted: 0.000016 | Actual: 0.000016
#   Predicted: 0.000013 | Actual: 0.000016
#   Predicted: 0.000011 | Actual: 0.000016
#
# Forecasted Future Values (based on future compound_score):
#   2025-01-02 -> Predicted Open: 0.000009
#   2025-01-03 -> Predicted Open: 0.000009
#   2025-01-04 -> Predicted Open: 0.000009
#   2025-01-05 -> Predicted Open: 0.000009
#   2025-01-06 -> Predicted Open: 0.000009
#   2025-01-07 -> Predicted Open: 0.000009
#   2025-01-08 -> Predicted Open: 0.000009
#   2025-01-09 -> Predicted Open: 0.000009
#   2025-01-10 -> Predicted Open: 0.000009
#   2025-01-11 -> Predicted Open: 0.000009
#   2025-01-12 -> Predicted Open: 0.000009
#   2025-01-13 -> Predicted Open: 0.000009
#   2025-01-14 -> Predicted Open: 0.000009
#   2025-01-15 -> Predicted Open: 0.000009
#   2025-01-16 -> Predicted Open: 0.000009
#   2025-01-17 -> Predicted Open: 0.000009
#   2025-01-18 -> Predicted Open: 0.000009
#   2025-01-19 -> Predicted Open: 0.000009
#   2025-01-20 -> Predicted Open: 0.000009
#   2025-01-21 -> Predicted Open: 0.000009
#   2025-01-22 -> Predicted Open: 0.000009
#   2025-01-23 -> Predicted Open: 0.000009
#   2025-01-24 -> Predicted Open: 0.000009
#   2025-01-25 -> Predicted Open: 0.000009
#   2025-01-26 -> Predicted Open: 0.000009
#   2025-01-27 -> Predicted Open: 0.000009
#   2025-01-28 -> Predicted Open: 0.000009
#   2025-01-29 -> Predicted Open: 0.000009
#   2025-01-30 -> Predicted Open: 0.000009
#   2025-01-31 -> Predicted Open: 0.000009
#   2025-02-01 -> Predicted Open: 0.000009
#   2025-02-02 -> Predicted Open: 0.000009
#   2025-02-03 -> Predicted Open: 0.000009
#   2025-05-26 -> Predicted Low: 0.000034
#   2025-05-27 -> Predicted Low: 0.000059
#   2025-05-28 -> Predicted Low: 0.000034
#   2025-05-29 -> Predicted Low: 0.000035
#   2025-05-30 -> Predicted Low: 0.000041
#   2025-05-31 -> Predicted Low: 0.000040
#   2025-06-01 -> Predicted Low: 0.000056
#   2025-06-02 -> Predicted Low: 0.000066
#   2025-06-03 -> Predicted Low: 0.000062
#   2025-06-04 -> Predicted Low: 0.000048
#   2025-06-05 -> Predicted Low: 0.000056
#   2025-06-06 -> Predicted Low: 0.000078
#   2025-06-07 -> Predicted Low: 0.000061
#   2025-06-08 -> Predicted Low: 0.000057
#   2025-06-09 -> Predicted Low: 0.000046
#   2025-06-10 -> Predicted Low: 0.000045
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\3642910970.py:28: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   test_dates = pd.to_datetime(datasets[coin]['Date'].iloc[-len(res['actuals']):], errors='coerce').dt.to_pydatetime()
# Target: Close
# Best Params: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Mean Squared Error (MSE): 0.00000000
# R² Score: -62953257.0510
#
# Predicted vs Actual (first 20 test samples):
#   Predicted: 0.000092 | Actual: 0.000099
#   Predicted: 0.000039 | Actual: 0.000099
#   Predicted: 0.000102 | Actual: 0.000099
#   Predicted: 0.000064 | Actual: 0.000099
#   Predicted: 0.000109 | Actual: 0.000099
#   Predicted: 0.000096 | Actual: 0.000099
#   Predicted: 0.000092 | Actual: 0.000099
#   Predicted: 0.000102 | Actual: 0.000099
#   Predicted: 0.000082 | Actual: 0.000099
#   Predicted: 0.000039 | Actual: 0.000099
#
# Forecasted Future Values (based on future compound_score):
#   2025-01-02 -> Predicted Close: 0.000032
#   2025-01-03 -> Predicted Close: 0.000032
#   2025-01-04 -> Predicted Close: 0.000032
#   2025-01-05 -> Predicted Close: 0.000032
#   2025-01-06 -> Predicted Close: 0.000032
#   2025-01-07 -> Predicted Close: 0.000032
#   2025-01-08 -> Predicted Close: 0.000032
#   2025-01-09 -> Predicted Close: 0.000032
#   2025-01-10 -> Predicted Close: 0.000032
#   2025-01-11 -> Predicted Close: 0.000032
#   2025-01-12 -> Predicted Close: 0.000031
#   2025-01-13 -> Predicted Close: 0.000031
#   2025-01-14 -> Predicted Close: 0.000031
#   2025-01-15 -> Predicted Close: 0.000031
#   2025-01-16 -> Predicted Close: 0.000031
#   2025-01-17 -> Predicted Close: 0.000031
#   2025-01-18 -> Predicted Close: 0.000034
#   2025-01-19 -> Predicted Close: 0.000034
#   2025-01-20 -> Predicted Close: 0.000034
#   2025-01-21 -> Predicted Close: 0.000034
#   2025-01-22 -> Predicted Close: 0.000033
#   2025-01-23 -> Predicted Close: 0.000033
#   2025-01-24 -> Predicted Close: 0.000033
#   2025-01-25 -> Predicted Close: 0.000033
#   2025-01-26 -> Predicted Close: 0.000033
#   2025-01-27 -> Predicted Close: 0.000033
#   2025-01-28 -> Predicted Close: 0.000033
#   2025-01-29 -> Predicted Close: 0.000033
#   2025-01-30 -> Predicted Close: 0.000033
#   2025-01-31 -> Predicted Close: 0.000033
#   2025-02-01 -> Predicted Close: 0.000033
#   2025-02-02 -> Predicted Close: 0.000034
#   2025-02-03 -> Predicted Close: 0.000034
#   2025-02-04 -> Predicted Close: 0.000033
#   2025-02-05 -> Predicted Close: 0.000035
#   2025-02-06 -> Predicted Close: 0.000035
#   2025-02-07 -> Predicted Close: 0.000035
#   2025-02-08 -> Predicted Close: 0.000035
#   2025-02-09 -> Predicted Close: 0.000042
#   2025-02-10 -> Predicted Close: 0.000042
#   2025-02-11 -> Predicted Close: 0.000042
#   2025-02-12 -> Predicted Close: 0.000045
#   2025-02-13 -> Predicted Close: 0.000045
#   2025-02-14 -> Predicted Close: 0.000041
#   2025-02-15 -> Predicted Close: 0.000041
#   2025-02-16 -> Predicted Close: 0.000041
#   2025-02-17 -> Predicted Close: 0.000041
#   2025-02-18 -> Predicted Close: 0.000041
#   2025-02-19 -> Predicted Close: 0.000041
#   2025-02-20 -> Predicted Close: 0.000055
#   2025-02-21 -> Predicted Close: 0.000055
#   2025-02-22 -> Predicted Close: 0.000111
#   2025-02-23 -> Predicted Close: 0.000111
#   2025-02-24 -> Predicted Close: 0.000111
#   2025-02-25 -> Predicted Close: 0.000136
#   2025-02-26 -> Predicted Close: 0.000136
#   2025-02-27 -> Predicted Close: 0.000139
#   2025-02-28 -> Predicted Close: 0.000139
#   2025-03-01 -> Predicted Close: 0.000139
#   2025-03-02 -> Predicted Close: 0.000141
#   2025-03-03 -> Predicted Close: 0.000141
#   2025-03-04 -> Predicted Close: 0.000129
#   2025-03-05 -> Predicted Close: 0.000127
#   2025-03-06 -> Predicted Close: 0.000095
#   2025-03-07 -> Predicted Close: 0.000093
#   2025-03-08 -> Predicted Close: 0.000085
#   2025-03-09 -> Predicted Close: 0.000094
#   2025-03-10 -> Predicted Close: 0.000052
#   2025-03-11 -> Predicted Close: 0.000052
#   2025-03-12 -> Predicted Close: 0.000046
#   2025-03-13 -> Predicted Close: 0.000045
#   2025-03-14 -> Predicted Close: 0.000045
#   2025-03-15 -> Predicted Close: 0.000045
#   2025-03-16 -> Predicted Close: 0.000045
#   2025-03-17 -> Predicted Close: 0.000043
#   2025-03-18 -> Predicted Close: 0.000046
#   2025-03-19 -> Predicted Close: 0.000054
#   2025-03-20 -> Predicted Close: 0.000069
#   2025-03-21 -> Predicted Close: 0.000060
#   2025-03-22 -> Predicted Close: 0.000059
#   2025-03-23 -> Predicted Close: 0.000096
#   2025-03-24 -> Predicted Close: 0.000113
#   2025-03-25 -> Predicted Close: 0.000111
#   2025-03-26 -> Predicted Close: 0.000101
#   2025-03-27 -> Predicted Close: 0.000095
#   2025-03-28 -> Predicted Close: 0.000097
#   2025-03-29 -> Predicted Close: 0.000119
#   2025-03-30 -> Predicted Close: 0.000117
#   2025-03-31 -> Predicted Close: 0.000117
#   2025-04-01 -> Predicted Close: 0.000112
#   2025-04-02 -> Predicted Close: 0.000102
#   2025-04-03 -> Predicted Close: 0.000104
#   2025-04-04 -> Predicted Close: 0.000104
#   2025-04-05 -> Predicted Close: 0.000101
#   2025-04-06 -> Predicted Close: 0.000099
#   2025-04-07 -> Predicted Close: 0.000100
#   2025-04-08 -> Predicted Close: 0.000092
#   2025-04-09 -> Predicted Close: 0.000092
#   2025-04-10 -> Predicted Close: 0.000109
#   2025-04-11 -> Predicted Close: 0.000092
#   2025-04-12 -> Predicted Close: 0.000128
#   2025-04-13 -> Predicted Close: 0.000118
#   2025-04-14 -> Predicted Close: 0.000110
#   2025-04-15 -> Predicted Close: 0.000096
#   2025-04-16 -> Predicted Close: 0.000138
#   2025-04-17 -> Predicted Close: 0.000138
#   2025-04-18 -> Predicted Close: 0.000096
#   2025-04-19 -> Predicted Close: 0.000100
#   2025-04-20 -> Predicted Close: 0.000089
#   2025-04-21 -> Predicted Close: 0.000109
#   2025-04-22 -> Predicted Close: 0.000107
#   2025-04-23 -> Predicted Close: 0.000103
#   2025-04-24 -> Predicted Close: 0.000096
#   2025-04-25 -> Predicted Close: 0.000099
#   2025-04-26 -> Predicted Close: 0.000091
#   2025-04-27 -> Predicted Close: 0.000092
#   2025-04-28 -> Predicted Close: 0.000085
#   2025-04-29 -> Predicted Close: 0.000099
#   2025-04-30 -> Predicted Close: 0.000085
#   2025-05-01 -> Predicted Close: 0.000082
#   2025-05-02 -> Predicted Close: 0.000099
#   2025-05-03 -> Predicted Close: 0.000093
#   2025-05-04 -> Predicted Close: 0.000088
#   2025-05-05 -> Predicted Close: 0.000092
#   2025-05-06 -> Predicted Close: 0.000085
#   2025-05-07 -> Predicted Close: 0.000095
#   2025-05-08 -> Predicted Close: 0.000084
#   2025-05-09 -> Predicted Close: 0.000077
#   2025-05-10 -> Predicted Close: 0.000078
#   2025-05-11 -> Predicted Close: 0.000082
#   2025-05-12 -> Predicted Close: 0.000081
#   2025-05-13 -> Predicted Close: 0.000090
#   2025-05-14 -> Predicted Close: 0.000057
#   2025-05-15 -> Predicted Close: 0.000056
#   2025-05-16 -> Predicted Close: 0.000038
#   2025-05-17 -> Predicted Close: 0.000041
#   2025-05-18 -> Predicted Close: 0.000119
#   2025-05-19 -> Predicted Close: 0.000032
#   2025-05-20 -> Predicted Close: 0.000029
#   2025-05-21 -> Predicted Close: 0.000030
#   2025-05-22 -> Predicted Close: 0.000030
#   2025-05-23 -> Predicted Close: 0.000029
#   2025-05-24 -> Predicted Close: 0.000041
#   2025-05-25 -> Predicted Close: 0.000039
#   2025-05-26 -> Predicted Close: 0.000038
#   2025-05-27 -> Predicted Close: 0.000059
#   2025-05-28 -> Predicted Close: 0.000038
#   2025-05-29 -> Predicted Close: 0.000038
#   2025-05-30 -> Predicted Close: 0.000045
#   2025-05-31 -> Predicted Close: 0.000043
#   2025-06-01 -> Predicted Close: 0.000060
#   2025-06-02 -> Predicted Close: 0.000068
#   2025-06-03 -> Predicted Close: 0.000066
#   2025-06-04 -> Predicted Close: 0.000051
#   2025-06-05 -> Predicted Close: 0.000060
#   2025-06-06 -> Predicted Close: 0.000083
#   2025-06-07 -> Predicted Close: 0.000060
#   2025-06-08 -> Predicted Close: 0.000058
#   2025-06-09 -> Predicted Close: 0.000049
#   2025-06-10 -> Predicted Close: 0.000047
# C:\Users\mnurh\AppData\Local\Temp\ipykernel_23700\3642910970.py:28: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   test_dates = pd.to_datetime(datasets[coin]['Date'].iloc[-len(res['actuals']):], errors='coerce').dt.to_pydatetime()
